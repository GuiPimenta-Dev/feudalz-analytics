# %%
import warnings
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from game import Game
from models import Player, Land, MockPlayer
from utils.fc import get_df_over_increase, plot_heroes_sum_diff, plot_heroes_mean_diff, simulation, get_hero_diff
from utils.mpl import plot_scatter, plot_line_with_scatter
GAMES = 100

# %%
# df = get_df_over_increase(enemy_defense_bonus=13.8)

# %%
# fig, ax = plt.subplots(figsize=(20, 10))

# ax.plot(df.my_attack_bonus , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus}')
# plot_scatter(df.my_attack_bonus,df.goldz)


# ax.set_xlabel('Attack Bonus',fontsize=20)
# ax.set_ylabel('Goldz',fontsize=20)

# plt.xticks(df.my_attack_bonus)
# ax.set_title(f"Goldz Average per Attack Bonus", fontsize=20)

# %%
# df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, group=True)
# df1 = simulation(my_defense_bonus=0, my_attack_bonus=16.25, enemy_defense_bonus=13.8, group=True)
# df2 = simulation(my_defense_bonus=0, my_attack_bonus=48.75, enemy_defense_bonus=13.8, group=True)
# df3 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8, group=True)

# %%
# fig, ax = plt.subplots(figsize=(20, 10))

# ax.plot(df.day , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus.mean()}')
# plot_scatter(df.day,df.goldz)

# ax.plot(df1.day , df1.goldz, marker='o',label=f'Attack bonus = {df1.my_attack_bonus.mean()}')
# plot_scatter(df1.day,df1.goldz)

# ax.plot(df2.day , df2.goldz, marker='o',label=f'Attack bonus = {df2.my_attack_bonus.mean()}')
# plot_scatter(df2.day,df2.goldz)

# ax.plot(df3.day , df3.goldz, marker='o',label=f'Attack bonus = {df3.my_attack_bonus.mean()}')
# plot_scatter(df3.day,df3.goldz)

# ax.set_xlabel('Days',fontsize=20)
# ax.set_ylabel('Goldz',fontsize=20)
# ax.legend(prop={'size': 20})
# plt.xticks(df.day)
# ax.set_title(f"Goldz average every 5 days", fontsize=20)

# %%
# x = plot_heroes_sum_diff(my_defense_bonus=13.8, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 0 Atk Bonus', games=GAMES, column='profit')
# y = plot_heroes_sum_diff(my_defense_bonus=13.8, my_attack_bonus=16.25, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 16.25 Atk Bonus',games=GAMES, column='profit')
# z = plot_heroes_sum_diff(my_defense_bonus=13.8, my_attack_bonus=32.5, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 32.5 Atk Bonus',games=GAMES, column='profit')
# a = plot_heroes_sum_diff(my_defense_bonus=13.8, my_attack_bonus=48.75, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 48.75 Atk Bonus',games=GAMES, column='profit')
# b = plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 65 Atk Bonus',games=GAMES, column='profit')

# %%
x = plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 0 Atk Bonus', games=GAMES)
y = plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 16.25 Atk Bonus', games=GAMES)
z = plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 32.5 Atk Bonus', games=GAMES)
a = plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 48.75 Atk Bonus', games=GAMES)
b = plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 65 Atk Bonus', games=GAMES)

# %%
# plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Energy Diff for Attack Compared to No Hero by Rarity - 0 Atk Bonus', games=GAMES, column='energy')
# plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Energy Diff for Attack Compared to No Hero by Rarity - 16.25 Atk Bonus', games=GAMES, column='energy')
# plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Energy Diff for Attack Compared to No Hero by Rarity - 32.5 Atk Bonus', games=GAMES, column='energy')
# plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Energy Diff for Attack Compared to No Hero by Rarity - 48.75 Atk Bonus', games=GAMES, column='energy')
# plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Energy Diff for Attack Compared to No Hero by Rarity - 65 Atk Bonus', games=GAMES, column='energy')

# %%
# plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Energy Average Diff for Attack Compared to No Hero by Rarity - 0 Def Bonus', games=GAMES, column='energy')
# plot_heroes_mean_diff(my_defense_bonus=18.75, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Energy Average Diff for Attack Compared to No Hero by Rarity - 18.75 Def Bonus', games=GAMES, column='energy')
# plot_heroes_mean_diff(my_defense_bonus=37.5, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Energy Average Diff for Attack Compared to No Hero by Rarity - 37.5 Def Bonus', games=GAMES, column='energy')
# plot_heroes_mean_diff(my_defense_bonus=56.25, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Energy Average Diff for Attack Compared to No Hero by Rarity - 56.25 Def Bonus', games=GAMES, column='energy')
# plot_heroes_mean_diff(my_defense_bonus=75, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Energy Average Diff for Attack Compared to No Hero by Rarity - 75 Def Bonus', games=GAMES, column='energy')

# %%
x
# Out:
#          dicez  urzog  kongz    lyz  etherman  vampirao
# rarity
# usual    0.428  0.439  0.338 -0.010     0.168    -0.032
# unusual  0.838  0.874  0.912 -0.124     0.487    -0.065
# rare     0.978  1.234  1.290  0.013     0.607    -0.133
# epic     1.134  1.632  1.998  0.037     0.730    -0.028

# %%
y
# Out:
#          dicez  urzog  kongz    lyz  etherman  vampirao
# rarity
# usual    0.644  0.305  0.386  0.060     0.062    -0.064
# unusual  0.873  0.592  0.910  0.063     0.299    -0.149
# rare     1.003  1.107  1.483  0.111     0.507    -0.050
# epic     1.188  1.452  1.984  0.072     0.730    -0.097

# %%
z
# Out:
#          dicez  urzog  kongz    lyz  etherman  vampirao
# rarity
# usual    0.431  0.372  0.406  0.047    -0.005     0.080
# unusual  0.754  0.890  0.965 -0.059     0.351     0.015
# rare     1.037  1.154  1.290 -0.141     0.542    -0.045
# epic     1.002  1.761  1.860 -0.024     0.654     0.018

# %%
a
# Out:
#          dicez  urzog  kongz    lyz  etherman  vampirao
# rarity
# usual    0.407  0.531  0.415  0.122     0.064    -0.041
# unusual  0.858  0.800  0.860  0.085     0.323    -0.089
# rare     1.066  1.175  1.318  0.153     0.471     0.084
# epic     1.271  1.780  1.701  0.107     0.720    -0.083

# %%
b
# Out:
#          dicez  urzog  kongz    lyz  etherman  vampirao
# rarity
# usual    0.563  0.432  0.328  0.002     0.144    -0.071
# unusual  0.845  0.796  0.850 -0.082     0.285    -0.023
# rare     1.214  1.308  1.361  0.023     0.434    -0.012
# epic     1.224  1.596  1.726  0.003     0.610     0.049
