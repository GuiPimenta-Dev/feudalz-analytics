# %%
import warnings
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from game import Game
from models import Player, Land, MockPlayer
from utils.fc import get_df_over_increase, plot_heroes_sum_diff, plot_heroes_mean_diff, simulation, get_hero_diff
from utils.mpl import plot_scatter, plot_line_with_scatter
GAMES = 1000

# %%
# df = get_df_over_increase(enemy_defense_bonus=13.8)

# %%
# fig, ax = plt.subplots(figsize=(20, 10))

# ax.plot(df.my_attack_bonus , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus}')
# plot_scatter(df.my_attack_bonus,df.goldz)


# ax.set_xlabel('Attack Bonus',fontsize=20)
# ax.set_ylabel('Goldz',fontsize=20)

# plt.xticks(df.my_attack_bonus)
# ax.set_title(f"Goldz Average per Attack Bonus", fontsize=20)

# %%
# df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, group=True)
# df1 = simulation(my_defense_bonus=0, my_attack_bonus=16.25, enemy_defense_bonus=13.8, group=True)
# df2 = simulation(my_defense_bonus=0, my_attack_bonus=48.75, enemy_defense_bonus=13.8, group=True)
# df3 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8, group=True)

# %%
# fig, ax = plt.subplots(figsize=(20, 10))

# ax.plot(df.day , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus.mean()}')
# plot_scatter(df.day,df.goldz)

# ax.plot(df1.day , df1.goldz, marker='o',label=f'Attack bonus = {df1.my_attack_bonus.mean()}')
# plot_scatter(df1.day,df1.goldz)

# ax.plot(df2.day , df2.goldz, marker='o',label=f'Attack bonus = {df2.my_attack_bonus.mean()}')
# plot_scatter(df2.day,df2.goldz)

# ax.plot(df3.day , df3.goldz, marker='o',label=f'Attack bonus = {df3.my_attack_bonus.mean()}')
# plot_scatter(df3.day,df3.goldz)

# ax.set_xlabel('Days',fontsize=20)
# ax.set_ylabel('Goldz',fontsize=20)
# ax.legend(prop={'size': 20})
# plt.xticks(df.day)
# ax.set_title(f"Goldz average every 5 days", fontsize=20)

# %%
plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 0 Atk Bonus', games=GAMES)
plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=16.25, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 16.25 Atk Bonus',games=GAMES)
plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=32.5, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 32.5 Atk Bonus',games=GAMES)
plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=48.75, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 48.75 Atk Bonus',games=GAMES)
plot_heroes_sum_diff(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8, label='Total Diff Goldz Bonus Compared to No Hero by Rarity - 65 Atk Bonus',games=GAMES)

# %%
plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 0 Atk Bonus', games=GAMES)
plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 16.25 Atk Bonus', games=GAMES)
plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 32.5 Atk Bonus', games=GAMES)
plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 48.75 Atk Bonus', games=GAMES)
plot_heroes_mean_diff(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, label='Goldz Average Diff for Attack Compared to No Hero by Rarity - 65 Atk Bonus', games=GAMES)
