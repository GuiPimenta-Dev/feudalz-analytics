# %%
import warnings
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from game import Game
from models import Player, Land, MockPlayer
from utils.fc import get_df_over_increase, create_mock_game, simulation
from utils.mpl import plot_scatter

# %%
df = simulation(my_defense_bonus=13.8,my_attack_bonus=0,enemy_defense_bonus=13.8,hero="tanker",rarity="epic", group=True)
df1 = simulation(my_defense_bonus=13.8,my_attack_bonus=0,enemy_defense_bonus=13.8, group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df.day , df.energy, marker='o',label=f'Tanker = {round(df.energy.mean(),2)}')
plot_scatter(df.day,df.energy)

ax.plot(df1.day , df1.energy, marker='o',label=f'No Hero = {round(df1.energy.mean(),2)}')
plot_scatter(df1.day,df1.energy)

ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Energy',fontsize=20)
ax.legend(prop={'size': 20}, title='Energy Average each 5 days')
plt.xticks(df.day)
ax.set_title(f"Tanker at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker at day 10 - 15')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8,group=True)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8,hero='tanker', rarity='usual', group=True)
df2 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8,hero='tanker', rarity='unusual', group=True)
df3 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8,hero='tanker', rarity='rare', group=True)
df4 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8,hero='tanker', rarity='epic', group=True)

# %%
bar_width = 1

fig, ax = plt.subplots(figsize=(20, 10))

ax.bar(df4[df4.day == 15].day + 2*bar_width, df4[df4.day == 15].energy, bar_width, label=f'Epic')
ax.bar(df3[df3.day == 15].day + bar_width, df3[df3.day == 15].energy, bar_width,label=f'Rare')
ax.bar(df2[df2.day == 15].day , df2[df2.day == 15].energy, bar_width,label=f'Unusual')
ax.bar(df1[df1.day == 15].day - bar_width, df1[df1.day == 15].energy, bar_width,label=f'Usual')
ax.bar(df[df.day == 15].day - 2 * bar_width, df[df.day == 15].energy, bar_width,label=f'No Hero')

plot_scatter(df[df.day == 15].day - 2*bar_width,df[df.day == 15].energy)
plot_scatter(df1[df1.day == 15].day- bar_width,df1[df1.day == 15].energy)
plot_scatter(df2[df2.day == 15].day ,df2[df2.day == 15].energy)
plot_scatter(df3[df3.day == 15].day + bar_width,df3[df3.day == 15].energy)
plot_scatter(df4[df4.day == 15].day + 2* bar_width,df4[df4.day == 15].energy)

ax.set_xlabel('Days',fontsize=20)
ax.legend(prop={'size': 20})
plt.xticks([10,15,20])
ax.set_title(f"Tanker Goldz average in 5 days", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker Goldz average in 5 days')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,group=True)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='usual', group=True)
df2 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='unusual', group=True)
df3 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='rare',group=True)
df4 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='epic',group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df4.day , df4.energy, marker='o',label=f'Epic = {round(df4.energy.mean(),2)}')
ax.plot(df3.day , df3.energy, marker='o',label=f'Rare = {round(df3.energy.mean(),2)}')
ax.plot(df2.day , df2.energy, marker='o',label=f'Unusual = {round(df2.energy.mean(),2)}')
ax.plot(df1.day , df1.energy, marker='o',label=f'Usual = {round(df1.energy.mean(),2)}')
ax.plot(df.day , df.energy, marker='o',label=f'No Hero = {round(df.energy.mean(),2)}')

ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Energy',fontsize=20)
ax.legend(prop={'size': 20}, title='Energy Average Each 5 days')
plt.xticks(df.day)
ax.set_title(f"Tanker at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker at day 10 - 15')

# %%
df = simulation(my_defense_bonus=13.8, my_attack_bonus=0, enemy_defense_bonus=13.8, group=True)
df1 = simulation(my_defense_bonus=13.8, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='usual', group=True)
df2 = simulation(my_defense_bonus=13.8, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='unusual', group=True)
df3 = simulation(my_defense_bonus=13.8, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='rare', group=True)
df4 = simulation(my_defense_bonus=13.8, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='epic', group=True)

# %%
bar_width = 1
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(df4.day , df4.heal_cost,label=f'Epic = {round(df4.heal_cost.mean(),2)}')
ax.plot(df3.day , df3.heal_cost, label=f'Rare = {round(df3.profit.mean(),2)}')
ax.plot(df2.day , df2.heal_cost, label=f'Unusual = {round(df2.profit.mean(),2)}')
ax.plot(df1.day , df1.heal_cost, label=f'Usual = {round(df1.heal_cost.mean(),2)}')
ax.plot(df.day , df.heal_cost,label=f'No Hero = {round(df.heal_cost.mean(),2)}')


ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Energy',fontsize=20)
ax.legend(prop={'size': 20}, title='Profit Average Each 5 days')
plt.xticks(df.day)
ax.set_title(f"Tanker at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker at day 10 - 15')
