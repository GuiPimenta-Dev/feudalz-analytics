# %%
import warnings
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from utils.mpl import plot_heroes_goldz_by_rarity, plot_heroes_total_goldz_by_rarity
GAMES = 1000

# %%
my_defense_bonus = enemy_defense_bonus = 50
my_attack_bonus = 0
while my_attack_bonus <= 65:
  x = plot_heroes_total_goldz_by_rarity(my_defense_bonus=my_defense_bonus, my_attack_bonus=my_attack_bonus,label=f'$GOLDZ Earned Compared to No Hero - {my_attack_bonus} Atk Bonus', games=GAMES)  
  my_attack_bonus += 16.25

# %%
my_defense_bonus = 0
my_attack_bonus = 0
while my_attack_bonus <= 65:
  x = plot_heroes_total_goldz_by_rarity(my_defense_bonus=my_defense_bonus, my_attack_bonus=my_attack_bonus,label=f'Profit Earned Compared to No Hero by Rarity - {my_attack_bonus} Atk Bonus - {my_defense_bonus} Def Bonus', games=GAMES)  
  my_attack_bonus += 16.25
  my_defense_bonus += 18.75
