# %%
import warnings
import pandas as pd
from pprint import pprint
import matplotlib as mpl
import matplotlib.pyplot as plt
from game import Game
from models import Player, Land, MockPlayer
# from utils.fc import get_df_grouped_by_days, get_df_over_increase, create_mock_game, get_df_grouped_by_days_with_heroes
from utils.fc import get_df_over_increase, create_mock_game, simulation
from utils.mpl import plot_scatter

# %%
df = get_df_over_increase(enemy_defense_bonus=13.8)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df.my_attack_bonus , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus}')
plot_scatter(df.my_attack_bonus,df.goldz)


ax.set_xlabel('Attack Bonus',fontsize=20)
ax.set_ylabel('Goldz',fontsize=20)

plt.xticks(df.my_attack_bonus)
ax.set_title(f"Goldz Average per Attack Bonus", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Goldz Average per Attack Bonus')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, group=True)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=16.25, enemy_defense_bonus=13.8, group=True)
df2 = simulation(my_defense_bonus=0, my_attack_bonus=48.75, enemy_defense_bonus=13.8, group=True)
df3 = simulation(my_defense_bonus=0, my_attack_bonus=65, enemy_defense_bonus=13.8, group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df.day , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus.mean()}')
plot_scatter(df.day,df.goldz)

ax.plot(df1.day , df1.goldz, marker='o',label=f'Attack bonus = {df1.my_attack_bonus.mean()}')
plot_scatter(df1.day,df1.goldz)

ax.plot(df2.day , df2.goldz, marker='o',label=f'Attack bonus = {df2.my_attack_bonus.mean()}')
plot_scatter(df2.day,df2.goldz)

ax.plot(df3.day , df3.goldz, marker='o',label=f'Attack bonus = {df3.my_attack_bonus.mean()}')
plot_scatter(df3.day,df3.goldz)



ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Goldz',fontsize=20)
ax.legend(prop={'size': 20})
plt.xticks(df.day)
ax.set_title(f"Goldz average every 5 days", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Goldz average every 5 days')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8, hero='urzog', group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df.day , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus.mean()}')
# ax.plot(df.day , df.goldz, marker='o',label=f'Attack bonus = {df.my_attack_bonus.mean()}')


plot_scatter(df.day,df.goldz)
ax.plot([10,15] , [df[df.day==10].goldz[2],df[df.day==15].goldz[3]], label='Urzog' )


ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Goldz',fontsize=20)
ax.legend(prop={'size': 20})
plt.xticks(df.day)
ax.set_title(f"Goldz average every 5 days", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Goldz average every 5 days')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,group=True)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='usual', group=True)
df2 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='unusual', group=True)
df3 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='rare',group=True)
df4 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='epic',group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df4.day , df4.goldz, marker='o',label=f'Epic = {round(df4.goldz.mean(),2)}')
ax.plot(df3.day , df3.goldz, marker='o',label=f'Rare = {round(df3.goldz.mean(),2)}')
ax.plot(df2.day , df2.goldz, marker='o',label=f'Unusual = {round(df2.goldz.mean(),2)}')
ax.plot(df1.day , df1.goldz, marker='o',label=f'Usual = {round(df1.goldz.mean(),2)}')
ax.plot(df.day , df.goldz, marker='o',label=f'No Hero = {round(df.goldz.mean(),2)}')

ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Goldz',fontsize=20)
ax.legend(prop={'size': 20}, title='Goldz Average Each 5 days')
plt.xticks(df.day)
ax.set_title(f"Urzog at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Urzog at day 10 - 15')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='usual')
df2 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='unusual')
df3 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='rare')
df4 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='urzog', rarity='epic')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(df4.day , df4.goldz, marker='o',label=f'Epic = {round(df4.goldz.mean(),2)}')
ax.plot(df3.day , df3.goldz, marker='o',label=f'Rare = {round(df3.goldz.mean(),2)}')
ax.plot(df2.day , df2.goldz, marker='o',label=f'Unusual = {round(df2.goldz.mean(),2)}')
ax.plot(df1.day , df1.goldz, marker='o',label=f'Usual = {round(df1.goldz.mean(),2)}')
ax.plot(df.day , df.goldz, marker='o',label=f'No Hero = {round(df.goldz.mean(),2)}')


ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Goldz',fontsize=20)
ax.legend(prop={'size': 20}, title='Goldz Average Each day')
plt.xticks(df.day)
ax.set_title(f"Urzog at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Urzog at day 10 - 15')

# %%
df = simulation(my_defense_bonus=0,my_attack_bonus=0,enemy_defense_bonus=13.8,hero="tanker",rarity="epic",group=True)
df1 = simulation(my_defense_bonus=0,my_attack_bonus=0,enemy_defense_bonus=13.8,group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df.day , df.energy, marker='o',label=f'Tanker = {round(df.my_defense_bonus.mean(),2)}')
# ax.plot([10,15] , [df[df.day==10].energy[2],df[df.day==15].energy[3]], label='Tanker' )
plot_scatter(df.day,df.energy)

ax.plot(df1.day , df1.energy, marker='o',label=f'No Hero = {round(df1.my_defense_bonus.mean(),2)}')
plot_scatter(df1.day,df1.energy)

ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Energy',fontsize=20)
ax.legend(prop={'size': 20}, title='Defense Bonus Average')
plt.xticks(df.day)
ax.set_title(f"Tanker at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker at day 10 - 15')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,group=True)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='usual', group=True)
df2 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='unusual', group=True)
df3 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='rare',group=True)
df4 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='epic',group=True)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(df4.day , df4.energy, marker='o',label=f'Epic = {round(df4.energy.mean(),2)}')
ax.plot(df3.day , df3.energy, marker='o',label=f'Rare = {round(df3.energy.mean(),2)}')
ax.plot(df2.day , df2.energy, marker='o',label=f'Unusual = {round(df2.energy.mean(),2)}')
ax.plot(df1.day , df1.energy, marker='o',label=f'Usual = {round(df1.energy.mean(),2)}')
ax.plot(df.day , df.energy, marker='o',label=f'No Hero = {round(df.energy.mean(),2)}')

ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Energy',fontsize=20)
ax.legend(prop={'size': 20}, title='Energy Average Each 5 days')
plt.xticks(df.day)
ax.set_title(f"Tanker at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker at day 10 - 15')

# %%
df = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8)
df1 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='usual')
df2 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='unusual')
df3 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='rare')
df4 = simulation(my_defense_bonus=0, my_attack_bonus=0, enemy_defense_bonus=13.8,hero='tanker', rarity='epic')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(df4.day , df4.energy, marker='o',label=f'Epic = {round(df4.energy.mean(),2)}')
ax.plot(df3.day , df3.energy, marker='o',label=f'Rare = {round(df3.energy.mean(),2)}')
ax.plot(df2.day , df2.energy, marker='o',label=f'Unusual = {round(df2.energy.mean(),2)}')
ax.plot(df1.day , df1.energy, marker='o',label=f'Usual = {round(df1.energy.mean(),2)}')
ax.plot(df.day , df.energy, marker='o',label=f'No Hero = {round(df.energy.mean(),2)}')


ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Energy',fontsize=20)
ax.legend(prop={'size': 20}, title='Energy Average Each day')
plt.xticks(df.day)
ax.set_title(f"Tanker at day 10 - 15", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Tanker at day 10 - 15')
